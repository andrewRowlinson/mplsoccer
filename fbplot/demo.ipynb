# %%
from pitch import FootballPitch

# %%
pitch = FootballPitch(pitch_type='statsbomb',orientation='vertical',view='half',layout=(1,1),
                      figsize=(10,10),goal_type='line',stripe=True,axis='off',xpad=(-20,0),ypad=(10,5))
ax = pitch.draw()

# %% [markdown]
# # Opta

# %% [markdown]
# #### Opta vertical full

# %%
pitch = FootballPitch(pitch_type='opta',orientation='vertical',view='full',layout=(1,1),figsize=(10,10),stripe=True,
                      goal_type='box')
ax = pitch.draw()
#ax[0].plot([39.56,39.56],[0,100])

# %% [markdown]
# #### Opta horizontal full

# %%
pitch = FootballPitch(pitch_type='opta',orientation='horizontal',view='full',layout=(1,1),figsize=(10,10),stripe=True,axis='on',
                     goal_type='line')
ax = pitch.draw()

# %% [markdown]
# #### Opta vertical half

# %%
pitch = FootballPitch(pitch_type='opta',orientation='vertical',view='half',layout=(1,1),figsize=(10,10),stripe=True,goal_type='line')
ax = pitch.draw()

# %% [markdown]
# #### Opta Horizontal half

# %%
pitch = FootballPitch(pitch_type='opta',orientation='horizontal',view='half',layout=(1,1),figsize=(10,10),stripe=True,goal_type='line')
ax = pitch.draw()

# %% [markdown]
# # Statsbomb

# %% [markdown]
# #### Statsbomb vertical full

# %%
pitch = FootballPitch(pitch_type='statsbomb',orientation='vertical',view='full',figsize=(10,10),stripe=True,goal_type='line')
ax = pitch.draw()

# %% [markdown]
# ## Statsbomb horizontal full

# %%
pitch = FootballPitch(pitch_type='statsbomb',orientation='horizontal',view='full',layout=(1,1),figsize=(10,10),stripe=True,axis='on',
                     goal_type='line')
ax = pitch.draw()

# %% [markdown]
# #### Statsbomb vertical half

# %% [markdown]
# #### Statsbomb Horizontal half

# %%
pitch = FootballPitch(pitch_type='statsbomb',orientation='horizontal',view='half',layout=(1,1),figsize=(10,10),stripe=True,
                     goal_type='line')
ax = pitch.draw()

# %% [markdown]
# # Tracab

# %% [markdown]
# #### Tracab vertical full

# %%
pitch = FootballPitch(pitch_type='tracab',orientation='vertical',view='full',layout=(1,1),figsize=(10,10),
                  pitch_width=68,pitch_length=105,stripe=True,goal_type='line')
ax = pitch.draw()

# %% [markdown]
# #### Tracab horizontal full

# %%
pitch = FootballPitch(pitch_type='tracab',orientation='horizontal',view='full',layout=(1,1),figsize=(10,10),
                  pitch_width=68,pitch_length=105,stripe=True,goal_type='line')
ax = pitch.draw()

# %% [markdown]
# #### Tracab vertical half

# %%
pitch = FootballPitch(pitch_type='tracab',orientation='vertical',view='half',layout=(1,1),figsize=(10,10),
                  pitch_width=68,pitch_length=105,stripe=True,goal_type='line')
ax = pitch.draw()

# %% [markdown]
# #### Tracab Horizontal half

# %%
pitch = FootballPitch(pitch_type='tracab',orientation='horizontal',view='half',layout=(1,1),figsize=(10,10),
                  pitch_width=68,pitch_length=105,stripe=True,goal_type='line')
ax = pitch.draw()

# %% [markdown]
# # Stats.com

# %% [markdown]
# #### stats.com vertical full

# %%
pitch = FootballPitch(pitch_type='stats',orientation='vertical',view='full',figsize=(10,10),stripe=True,axis='on',
                     goal_type='line')
ax = pitch.draw()

# %% [markdown]
# #### stats.com horizontal full

# %%
pitch = FootballPitch(pitch_type='stats',orientation='horizontal',view='full',layout=(1,1),figsize=(10,10),stripe=True,axis='on',
                     goal_type='line')
ax = pitch.draw()

# %% [markdown]
# #### stats.com vertical half

# %%
pitch = FootballPitch(pitch_type='stats',orientation='vertical',view='half',layout=(1,1),figsize=(10,10),stripe=True,axis='on',
                     goal_type='line')
ax = pitch.draw()

# %% [markdown]
# #### stats.com Horizontal half

# %%
pitch = FootballPitch(pitch_type='stats',orientation='horizontal',view='half',layout=(1,1),figsize=(10,10),stripe=True,axis='on',
                     goal_type='line')
ax = pitch.draw()

# %% [markdown]
# # Wyscout

# %% [markdown]
# #### wyscout vertical full

# %%
pitch = FootballPitch(pitch_type='wyscout',orientation='vertical',view='full',figsize=(10,10),stripe=True,axis='on',
                     goal_type='line')
ax = pitch.draw()

# %% [markdown]
# #### wyscout horizontal full

# %%
pitch = FootballPitch(pitch_type='wyscout',orientation='horizontal',view='full',layout=(1,1),figsize=(10,10),stripe=True,axis='on',
                     goal_type='line')
ax = pitch.draw()

# %% [markdown]
# #### wyscout vertical half

# %%
pitch = FootballPitch(pitch_type='wyscout',orientation='vertical',view='half',layout=(1,1),figsize=(10,10),stripe=True,axis='on',
                     goal_type='line')
ax = pitch.draw()

# %% [markdown]
# #### wyscout Horizontal half

# %%
pitch = FootballPitch(pitch_type='wyscout',orientation='horizontal',view='half',layout=(1,1),figsize=(10,10),stripe=True,axis='on',goal_type='line')
ax = pitch.draw()
